# %%
import os 
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data1=df=pd.read_csv("Sales1.csv")

# %%
data1.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %% [markdown]
# #                                          Sample Sales Data
# #                                        Exploratory Analysis
# ###                                                 Hayden Horn, hhorn@bellarmine.edu

# %%
data1.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
data1['ORDERNUMBER'].mean()
# Out:
# 10258.725115125753

# %%
data1['ORDERNUMBER'].min()
# Out:
# 10100

# %%
data1['ORDERNUMBER'].max()
# Out:
# 10425

# %%
data1['ORDERNUMBER'].count()
# Out:
# 2823

# %%
data1['QUANTITYORDERED'].mean()
# Out:
# 35.09280906836698

# %%
data1['QUANTITYORDERED'].max()
# Out:
# 97

# %%
data1['QUANTITYORDERED'].min()
# Out:
# 6

# %%
data1['PRICEEACH'].mean()
# Out:
# 83.65854410201929

# %%
data1['PRICEEACH'].min()
# Out:
# 26.88

# %%
data1['PRICEEACH'].max()
# Out:
# 100.0

# %%
data1['SALES'].mean()
# Out:
# 3553.88907190932

# %%
data1['SALES'].min()
# Out:
# 482.13

# %%
data1['SALES'].max()
# Out:
# 14082.8

# %%
data1['QTR_ID'].mean()
# Out:
# 2.7176762309599716

# %%
data1['QTR_ID'].max()
# Out:
# 4

# %%
data1['QTR_ID'].min()
# Out:
# 1

# %%
data1['MONTH_ID'].mean()
# Out:
# 7.0924548352816155

# %%
data1['MONTH_ID'].max()
# Out:
# 12

# %%
data1['MONTH_ID'].min()
# Out:
# 1

# %%
data1['YEAR_ID'].mean()
# Out:
# 2003.8150903294368

# %%
data1['YEAR_ID'].max()
# Out:
# 2005

# %%
data1['YEAR_ID'].min()
# Out:
# 2003

# %%
data1['MSRP'].mean()
# Out:
# 100.71555083244775

# %%
data1['MSRP'].max()
# Out:
# 214

# %%
data1['MSRP'].min()
# Out:
# 33

# %%
plt.hist(data1['PRICEEACH'],
        facecolor = 'lightgreen',
        edgecolor='blue',
        bins=10)
plt.show()

# %%
line_plot=sns.lineplot(x='MONTH_ID', y='SALES', data=data1)

# %%
x=sns.lineplot(x='YEAR_ID', y='SALES', data=data1,)

# %%
box_plot=sns.boxplot(data1['MSRP'])
# Out:
# C:\Users\hayde\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.heatmap(data1.corr());

# %%
plt.scatter(data1['YEAR_ID'],data1['SALES'])

# %%
sns.scatterplot(x='QUANTITYORDERED',y='PRICEEACH',data=data1)
# Out:
# <AxesSubplot:xlabel='QUANTITYORDERED', ylabel='PRICEEACH'>

# %%
Pair_plot=sns.pairplot(data1[['QUANTITYORDERED','MSRP', 'SALES']])

# %%
plt.bar(data1['QUANTITYORDERED'],data1['PRICEEACH'])
plt.ylabel('PRICE')
plt.xlabel('QUANTITY ORDERED')
plt.title('QUANTITY VS PRICE')
# Out:
# Text(0.5, 1.0, 'QUANTITY VS PRICE')

# %%
sns.scatterplot(x='QUANTITYORDERED', y='SALES', data=data1)
# Out:
# <AxesSubplot:xlabel='QUANTITYORDERED', ylabel='SALES'>
